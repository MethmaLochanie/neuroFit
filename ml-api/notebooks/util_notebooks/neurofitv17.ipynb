# %%
# Import required module
import os
import subprocess


try:
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    from PIL import Image
    import glob
    from tqdm import tqdm
    import seaborn as sns
    import torch
    import torchvision.models as models
    import torchvision.transforms as transforms
    import torch.nn as nn
    import torch.nn.functional as F
    from torch_geometric.nn import GCNConv
    from scipy.stats import rankdata
    from torch.utils.data import Dataset
    from collections import defaultdict
    import random
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler
    from torch_geometric.utils import add_self_loops
    from sklearn.metrics import roc_auc_score
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.metrics import precision_score, recall_score, f1_score, ndcg_score
    from itertools import chain
    from sklearn.manifold import TSNE
    import networkx as nx
    from torchvision import models, transforms
    import torch
    # import torch_xla
    # import torch_xla.core.xla_model as xm
    import gc
    import pickle
    import zipfile 
    # import torch_xla
    # import torch_xla.core.xla_model as xm
    
except ImportError:
    print("Installing dependencies...")

    # Install system-level dependencies
    subprocess.run(["apt-get", "update"])
    subprocess.run(["apt-get", "install", "-y", "libcairo2", "libcairo2-dev"])

    # Install Python packages
    subprocess.run(["pip", "install", "--quiet", "pycairo"])
    subprocess.run(["pip", "install", "--quiet", "torch torchvision torchaudio"])
    subprocess.run(["pip", "install", "--quiet", "torch-geometric", "torch-scatter", "torch-sparse", "torch-cluster", "torch-spline-conv"])
    subprocess.run(["pip", "install", "--quiet", "pandas", "numpy", "matplotlib", "pillow", "tqdm", "seaborn", "scipy"])
    subprocess.run(["pip", "install", "--quiet", "scikit-learn"])
    subprocess.run(["pip", "install", "--quiet", "networkx", "Image", "glob", "torch_xla"])

    print("All dependencies installed.")


print("✅ All required dependencies are installed!")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch_geometric/typing.py:86: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /usr/local/lib/python3.10/dist-packages/torch_scatter/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-scatter'. "
# /usr/local/lib/python3.10/dist-packages/torch_geometric/typing.py:97: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /usr/local/lib/python3.10/dist-packages/torch_cluster/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-cluster'. "
# /usr/local/lib/python3.10/dist-packages/torch_geometric/typing.py:113: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /usr/local/lib/python3.10/dist-packages/torch_spline_conv/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch_geometric/typing.py:124: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /usr/local/lib/python3.10/dist-packages/torch_sparse/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   warnings.warn(f"An issue occurred while importing 'torch-sparse'. "
# ✅ All required dependencies are installed!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import glob
from tqdm import tqdm
import seaborn as sns
import torch
import torchvision.models as models
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from scipy.stats import rankdata
from torch.utils.data import Dataset
from collections import defaultdict
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch_geometric.utils import add_self_loops
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_score, recall_score, f1_score, ndcg_score
from itertools import chain
from sklearn.manifold import TSNE
import networkx as nx
from torchvision import models, transforms
# import torch
# import torch_xla
# import torch_xla.core.xla_model as xm
import gc
import pickle
import zipfile 
# import torch_xla
# import torch_xla.core.xla_model as xm
# import torch
# import dgl
import numpy as np
# from dgl import add_self_loop
import faiss
from torch_geometric.data import HeteroData
from torch_geometric.utils import add_self_loops

# %%
# Check if TPU is available
# device = xm.xla_device()
# print(f"✅ Using device: {device}")
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# dtype = torch.float16 if torch.cuda.is_available() else torch.bfloat16

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✅ Using device: {device}")
dtype = torch.float16 if torch.cuda.is_available() else torch.bfloat16
# Out:
# ✅ Using device: cuda

# %%
# Adjust article ID format
def adjust_id(x):
    x = str(x)
    return "0" + x if len(x) == 9 else x

# %%
# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
PREPROCESSED_DIR = "/kaggle/input/preprocessed-data"

# # ✅ Define file paths for saving preprocessed data
# PREPROCESSED_DIR = "/kaggle/working/preprocessed-data"
# ZIP_FILE = "/kaggle/working/preprocessed-data.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(PREPROCESSED_DIR, exist_ok=True)

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(PREPROCESSED_DIR, "articles_with_images.pkl")):
    print("✅ Preprocessed data already exists. Loading...")

    with open(os.path.join(PREPROCESSED_DIR, "articles_with_images.pkl"), "rb") as f:
        articles_with_images = pickle.load(f)

    with open(os.path.join(PREPROCESSED_DIR, "transactions_filtered.pkl"), "rb") as f:
        transactions_filtered = pickle.load(f)

    with open(os.path.join(PREPROCESSED_DIR, "customers_processed.pkl"), "rb") as f:
        customers = pickle.load(f)

    print("✅ Preprocessed data loaded successfully!")

else :
    print("⚡ Running preprocessing for the first time...")
    articles = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/articles.csv')
    customers = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/customers.csv')
    transactions = pd.read_csv('/kaggle/input/h-and-m-personalized-fashion-recommendations/transactions_train.csv')

    # Get all paths from the image folder
    all_image_paths = glob.glob("/kaggle/input/h-and-m-personalized-fashion-recommendations/images/*/*")
    
    # Adjust the article ID and product code to be string & add "0"
    articles["article_id"] = articles["article_id"].apply(lambda x: adjust_id(x))
    articles["product_code"] = articles["article_id"].apply(lambda x: x[:3])
    
    # Get all valid article IDs and create a set to store image IDs
    all_image_ids = set()
    
    for path in tqdm(all_image_paths, desc="Processing Images"):
        article_id = os.path.basename(path).split('.')[0]  # Extract image ID from filename
        all_image_ids.add(article_id)
    
    
    # Construct full image paths and filter invalid ones
    images_path = "/kaggle/input/h-and-m-personalized-fashion-recommendations/images/"
    articles["path"] = articles["article_id"].apply(
        lambda x: images_path + x[:3] + "/" + x + ".jpg" if x in all_image_ids else None
    )
    
    # ✅ Keep only articles with valid images
    articles_with_images = articles.dropna(subset=["path"]).reset_index(drop=True)

    # Adjust the article ID and product code to be string & add "0"

    articles_with_images["article_id"] = articles_with_images["article_id"].astype("category")
    articles_with_images["product_code"] = articles_with_images["product_code"].astype("category")

    # Fill missing values
    customers.fillna({
        "FN": 0,
        "Active": 0,
        "club_member_status": "UNKNOWN",
        "fashion_news_frequency": "UNKNOWN",
        "age": customers["age"].median()
    }, inplace=True)
    
    customers["customer_id"] = customers["customer_id"].astype("category")
    customers["Active"] = customers["Active"].astype(np.int8)
    customers["FN"] = customers["FN"].astype(np.int8)
    customers["age"] = customers["age"].astype(np.float16)

    if 'age' in customers.columns:
        scaler_age = MinMaxScaler()
        customers['normalized_age'] = scaler_age.fit_transform(customers[['age']])
    else:
        raise ValueError("Error: `age` column is missing in customers!")
    
    # customers["fashion_news_frequency"] = customers["fashion_news_frequency"].replace({"None": "NONE"})
    # customers["age_interval"] = customers["age"].apply(create_age_interval)

    # Adjust article_id (as did for articles dataframe)
    transactions["article_id"] = transactions["article_id"].apply(lambda x: adjust_id(x))
    
    # Filter the transactions dataset to keep only valid article IDs
    transactions_filtered = transactions[transactions["article_id"].isin(set(articles_with_images["article_id"]))].reset_index(drop=True)
    
    # Optionally save the filtered transactions dataset
    # transactions_filtered.to_csv("transactions_filtered.csv", index=False)
    transactions_filtered["article_id"] = transactions_filtered["article_id"].astype("category")
    transactions_filtered["price"] = transactions_filtered["price"].astype(np.float16)

    # ✅ Save preprocessed data locally
    with open(os.path.join(PREPROCESSED_DIR, "articles_with_images.pkl"), "wb") as f:
        pickle.dump(articles_with_images, f)

    with open(os.path.join(PREPROCESSED_DIR, "transactions_filtered.pkl"), "wb") as f:
        pickle.dump(transactions_filtered, f)

    with open(os.path.join(PREPROCESSED_DIR, "customers_processed.pkl"), "wb") as f:
        pickle.dump(customers, f)

    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(ZIP_FILE, 'w') as zipf:
        for file in os.listdir(PREPROCESSED_DIR):
            zipf.write(os.path.join(PREPROCESSED_DIR, file), arcname=file)

    print(f"✅ Preprocessing completed! Saved as {ZIP_FILE}")
# Out:
# ✅ Preprocessed data already exists. Loading...
# ✅ Preprocessed data loaded successfully!

# %%
gc.collect()
torch.cuda.empty_cache()  # If using GPU

# %%
# Set random seed for reproducibility
np.random.seed(42)
random.seed(42)

# %% [markdown]
# creating embeddings

# %%
# # ✅ Define file paths for saving preprocessed data
# IMAGE_EMBEDDINGS_DIR = "/kaggle/working/image_embeddings"
# IMAGE_EMBEDDINGS_ZIP_FILE = "/kaggle/working/image_embeddings.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(IMAGE_EMBEDDINGS_DIR, exist_ok=True)

# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
IMAGE_EMBEDDINGS_DIR = "/kaggle/input/image-embeddings"

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(IMAGE_EMBEDDINGS_DIR, "image_embeddings.pkl")):
    print("✅ image_embeddings data already exists. Loading...")

    with open(os.path.join(IMAGE_EMBEDDINGS_DIR, "image_embeddings.pkl"), "rb") as f:
        image_embeddings = pickle.load(f)

    print("✅ image embeddings data loaded successfully!")

else:
    print("⚡ Extracting image embeddings for the first time...")

    # ✅ Load pre-trained ResNet50 model (Feature Extraction)
    resnet_model = models.resnet50(pretrained=True)
    resnet_model = torch.nn.Sequential(*list(resnet_model.children())[:-1])  # Remove the last FC layer
    resnet_model = resnet_model.to(device).eval()  # Move to device & set to eval mode

    # ✅ Define image transformations
    transform = transforms.Compose([
        transforms.Resize((224, 224)),  
        transforms.ToTensor(),          
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  
    ])

    # ✅ Function to extract image embeddings
    def get_image_embeddings_batch(image_paths_batch):
        images = [Image.open(path).convert('RGB') for path in image_paths_batch]
        images = [transform(image).unsqueeze(0) for image in images]
        images_tensor = torch.cat(images, dim=0).to(device)

        with torch.no_grad():
            features = resnet_model(images_tensor).squeeze(-1).squeeze(-1)  # Remove extra dimensions
        
        return features.cpu().numpy()

    # ✅ Process images in batches to avoid memory issues
    batch_size = 544  # Adjust batch size based on available memory
    image_embeddings = []

    for i in tqdm(range(0, len(articles_with_images), batch_size), desc="Extracting Features"):
        image_paths_batch = articles_with_images['path'][i:i + batch_size]
        embeddings_batch = get_image_embeddings_batch(image_paths_batch)
        image_embeddings.extend(embeddings_batch)

    # ✅ Convert to efficient tensor format
    image_embeddings = torch.tensor(image_embeddings, dtype=dtype).to(device)

    # ✅ Save preprocessed data locally
    with open(os.path.join(IMAGE_EMBEDDINGS_DIR, "image_embeddings.pkl"), "wb") as f:
        pickle.dump(image_embeddings, f)


    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(IMAGE_EMBEDDINGS_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(IMAGE_EMBEDDINGS_DIR):
            zipf.write(os.path.join(IMAGE_EMBEDDINGS_DIR, file), arcname=file)

    print(f"✅ image_embeddings completed! Saved as {IMAGE_EMBEDDINGS_ZIP_FILE}")
# Out:
# ✅ image_embeddings data already exists. Loading...
# ✅ image embeddings data loaded successfully!

# %%
# # ✅ Define file paths for saving preprocessed data
# TEXT_EMBEDDINGS_DIR = "/kaggle/working/text_embeddings"
# TEXT_EMBEDDINGS_ZIP_FILE = "/kaggle/working/text_embeddings.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(TEXT_EMBEDDINGS_DIR, exist_ok=True)

# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
TEXT_EMBEDDINGS_DIR = "/kaggle/input/text-embeddings"

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(TEXT_EMBEDDINGS_DIR, "text_embeddings.pkl")):
    print("✅ text_embeddings data already exists. Loading...")

    with open(os.path.join(TEXT_EMBEDDINGS_DIR, "text_embeddings.pkl"), "rb") as f:
        text_embeddings = pickle.load(f)

    print("✅ text embeddings data loaded successfull")

else :

    # Define text features
    if all(col in articles_with_images.columns for col in ['detail_desc', 'prod_name', 'product_type_name', 'product_group_name',
                                               'graphical_appearance_name', 'colour_group_name', 'index_name',
                                               'index_group_name', 'section_name', 'garment_group_name']):
        articles_with_images['text_data'] = (
            articles_with_images['detail_desc'].fillna('') + ' ' +
            articles_with_images['prod_name'].fillna('') + ' ' +
            articles_with_images['product_type_name'].fillna('') + ' ' +
            articles_with_images['product_group_name'].fillna('') + ' ' +
            articles_with_images['graphical_appearance_name'].fillna('') + ' ' +
            articles_with_images['colour_group_name'].fillna('') + ' ' +
            articles_with_images['index_name'].fillna('') + ' ' +
            articles_with_images['index_group_name'].fillna('') + ' ' +
            articles_with_images['section_name'].fillna('') + ' ' +
            articles_with_images['garment_group_name'].fillna('')
        )
    else:
        raise ValueError("Error: One or more textual columns are missing!")

    
    # Load pre-trained GloVe embeddings (for example, GloVe 100D embeddings)
    def load_glove_embeddings(glove_file_path):
        embeddings_index = {}
        with open(glove_file_path, 'r', encoding='utf-8') as f:
            for line in f:
                values = line.split()
                word = values[0]
                vector = np.asarray(values[1:], dtype='float32')
                embeddings_index[word] = vector
        return embeddings_index
    
    # Example usage (change the path to your GloVe file)
    glove_file_path = '/kaggle/input/test-feature-1/glove.6B.100d.txt'
    embeddings_index = load_glove_embeddings(glove_file_path)
    
    # Checking a sample word embedding
    # print(embeddings_index['king'])  # Example of checking the embedding for 'king'

    # Function to convert text data to embeddings using GloVe
    def text_to_glove_embeddings(text_data, embeddings_index, embedding_dim=100):
        embeddings = []
        for text in text_data:
            words = text.split()  # Split the text into words
            word_embeddings = np.zeros(embedding_dim)
            valid_word_count = 0
            
            # For each word, get its GloVe embedding (if it exists)
            for word in words:
                if word in embeddings_index:
                    word_embeddings += embeddings_index[word]
                    valid_word_count += 1
            
            # Average the embeddings of the words in the text
            if valid_word_count > 0:
                word_embeddings /= valid_word_count
            embeddings.append(word_embeddings)
        
        return np.array(embeddings)
    
    # Convert the product descriptions to GloVe embeddings
    text_embeddings = text_to_glove_embeddings(articles_with_images['text_data'], embeddings_index)


    # ✅ Save preprocessed data locally
    with open(os.path.join(TEXT_EMBEDDINGS_DIR, "text_embeddings.pkl"), "wb") as f:
        pickle.dump(text_embeddings, f)


    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(TEXT_EMBEDDINGS_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(TEXT_EMBEDDINGS_DIR):
            zipf.write(os.path.join(TEXT_EMBEDDINGS_DIR, file), arcname=file)

    print(f"✅ text_embeddings completed! Saved as {TEXT_EMBEDDINGS_ZIP_FILE}")
# Out:
# ✅ text_embeddings data already exists. Loading...
# ✅ text embeddings data loaded successfull

# %%
# # ✅ Define file paths for saving preprocessed data
# CUSTOMER_EMBEDDINGS_DIR = "/kaggle/working/customer_embeddings"
# CUSTOMER_EMBEDDINGS_ZIP_FILE = "/kaggle/working/customer_embeddings.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(CUSTOMER_EMBEDDINGS_DIR, exist_ok=True)

# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
CUSTOMER_EMBEDDINGS_DIR = "/kaggle/input/customer-embeddings"

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(CUSTOMER_EMBEDDINGS_DIR, "customer_embeddings.pkl")):
    print("✅ customer_embeddings data already exists. Loading...")

    with open(os.path.join(CUSTOMER_EMBEDDINGS_DIR, "customer_embeddings.pkl"), "rb") as f:
        customer_embeddings = pickle.load(f)

    print("✅ customer_embeddings data loaded successfull")

else :

    # Step 2: One-Hot Encode Categorical Features and Convert to float32
    categorical_features_encoded = pd.get_dummies(customers[['Active', 'club_member_status']]).astype(np.float32)
    
    # Step 3: Combine Both Categorical and Numerical Features (Ensure float32)
    customer_features = np.hstack([
        customers['normalized_age'].values.reshape(-1, 1).astype(np.float32),  
        categorical_features_encoded.astype(np.float32)
    ])
    
    # Convert to Tensor and Move to GPU
    customer_features_tensor = torch.tensor(customer_features, dtype=torch.float32).to(device)
    
    # Step 4: Use a Neural Network to Create the Customer Embedding
    class CustomerEmbedding(nn.Module):
        def __init__(self, input_dim, embedding_dim):
            super(CustomerEmbedding, self).__init__()
            self.fc1 = nn.Linear(input_dim, 128)  # Hidden layer
            self.fc2 = nn.Linear(128, embedding_dim)  # Output layer: Customer embedding
    
        def forward(self, x):
            x = torch.relu(self.fc1(x))
            x = self.fc2(x)
            return x
    
    # Define the model
    embedding_dim = 64  # Size of the customer embedding
    model = CustomerEmbedding(input_dim=customer_features.shape[1], embedding_dim=embedding_dim).to(device)  # Move the model to GPU
    
    # Convert the customer features into a tensor and move it to GPU
    customer_features_tensor = torch.tensor(customer_features, dtype=torch.float32).to(device)
    
    # Get customer embeddings by passing through the model
    customer_embeddings = model(customer_features_tensor)
    
    # Move the embeddings back to CPU if needed (optional)
    customer_embeddings = customer_embeddings.cpu().detach().numpy()
    customer_embeddings = torch.tensor(customer_embeddings, dtype=dtype).to(device)
    
    
     # ✅ Save preprocessed data locally
    with open(os.path.join(CUSTOMER_EMBEDDINGS_DIR, "customer_embeddings.pkl"), "wb") as f:
        pickle.dump(customer_embeddings, f)


    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(CUSTOMER_EMBEDDINGS_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(CUSTOMER_EMBEDDINGS_DIR):
            zipf.write(os.path.join(CUSTOMER_EMBEDDINGS_DIR, file), arcname=file)

    print(f"✅ customer_embeddings completed! Saved as {CUSTOMER_EMBEDDINGS_ZIP_FILE}")
# Out:
# ✅ customer_embeddings data already exists. Loading...
# ✅ customer_embeddings data loaded successfull

# %%
edge_types = ["product_to_product", "customer_to_product", "customer_to_customer"]

# %%
def sliced_wasserstein_distance(P, Q, num_projections=50):
    """
    Computes the Sliced Wasserstein Distance (SWD) between two trajectory distributions P and Q.
    Uses random projections to compute the distance between the two distributions.
    """
    device = P.device
    proj_vectors = torch.randn((P.shape[1], num_projections), device=device)  # Random projection vectors
    proj_vectors = proj_vectors / torch.norm(proj_vectors, dim=0, keepdim=True)  # Normalize

    P_proj = P @ proj_vectors  # Project P onto vectors
    Q_proj = Q @ proj_vectors  # Project Q onto vectors

    P_sorted, _ = torch.sort(P_proj, dim=0)
    Q_sorted, _ = torch.sort(Q_proj, dim=0)

    return torch.mean(torch.abs(P_sorted - Q_sorted))

# %% [markdown]
# data splitting

# %%
### Step 6: Geometric Distributed Sampling (GDS)
def geometric_distributed_sampling(ranks, rho=0.5, max_samples=300000):
    """
    Optimized Geometric Distributed Sampling (GDS).
    Ensures probabilities remain valid by normalizing ranks.
    """
    sorted_indices = torch.argsort(ranks, descending=True)
    max_categories = min(len(ranks), 16_000_000)  
    filtered_indices = sorted_indices[:max_categories] 

    # Normalize ranks
    ranks_subset = ranks[filtered_indices]
    normalized_ranks = (ranks_subset - ranks_subset.min()) / (ranks_subset.max() - ranks_subset.min() + 1e-8)

    # Compute probabilities
    probabilities = torch.exp(-rho * normalized_ranks)
    probabilities /= probabilities.sum()  # Normalize to sum = 1

    # Sample indices
    sampled_relative_indices = torch.multinomial(probabilities, num_samples=min(max_samples, len(filtered_indices)), replacement=False)

    # Map back to original transaction indices
    sampled_indices = filtered_indices[sampled_relative_indices]

    return sampled_indices.cpu()

# %%
# # ✅ Define file paths for saving preprocessed data
# DATA_SPLITTING_DIR = "/kaggle/working/data_splitting"
# DATA_SPLITTING_ZIP_FILE = "/kaggle/working/data_splitting.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(DATA_SPLITTING_DIR, exist_ok=True)

# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
DATA_SPLITTING_DIR = "/kaggle/input/data-splitting/data_splitting_2"

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl")):
    print("✅ train_data data already exists. Loading...")

    # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl"), "rb") as f:
        train_data = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "val_data.pkl"), "rb") as f:
        val_data = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "test_data.pkl"), "rb") as f:
        test_data = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "train_customers.pkl"), "rb") as f:
        train_customers = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "val_customers.pkl"), "rb") as f:
        val_customers = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "test_customers.pkl"), "rb") as f:
        test_customers = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "train_articles.pkl"), "rb") as f:
        train_articles = pickle.load(f)

        # Load extracted data
    with open(os.path.join(DATA_SPLITTING_DIR, "val_articles.pkl"), "rb") as f:
        val_articles = pickle.load(f)

    with open(os.path.join(DATA_SPLITTING_DIR, "test_articles.pkl"), "rb") as f:
        test_articles = pickle.load(f)

    print("✅ SPLIT data loaded successfully!")

else :

    print("⚡ Extracting SPLIT for the first time...")

    ### Step 3: Convert transaction date to datetime
    transactions_filtered['t_dat'] = pd.to_datetime(transactions_filtered['t_dat'])
    
    # Sort transactions by date
    transactions_filtered = transactions_filtered.sort_values('t_dat', ascending=True)
    
    ### Step 4: Compute train, validation, and test cutoffs
    cutoffs = transactions_filtered['t_dat'].quantile([0.75, 0.875, 1.0]).values
    train_cutoff, val_cutoff, test_cutoff = cutoffs  # 75% Train, 12.5% Val, 12.5% Test
    
    ### Step 5: Assign Ranks Efficiently for GDS
    transactions_filtered["rank"] = transactions_filtered['t_dat'].rank(method="first", ascending=True)
    
    # Convert ranks to a tensor
    ranks_tensor = torch.tensor(transactions_filtered["rank"].to_numpy(dtype=np.float32), device=device)
    
    # Get sampled transactions
    sampled_indices = geometric_distributed_sampling(ranks_tensor, rho=0.5, max_samples=300000)
    transactions_filtered_sampled = transactions_filtered.iloc[sampled_indices.numpy()].reset_index(drop=True)

    ### Step 7: Train/Validation/Test Splitting
    train_mask = transactions_filtered_sampled['t_dat'] <= train_cutoff
    val_mask = (transactions_filtered_sampled['t_dat'] > train_cutoff) & (transactions_filtered_sampled['t_dat'] <= val_cutoff)
    test_mask = (transactions_filtered_sampled['t_dat'] > val_cutoff) & (transactions_filtered_sampled['t_dat'] <= test_cutoff)
    
    train_data = transactions_filtered_sampled[train_mask]
    val_data = transactions_filtered_sampled[val_mask]
    test_data = transactions_filtered_sampled[test_mask]
    
    ### Step 8: Cold Start Customer Handling
    transaction_customers = set(transactions_filtered['customer_id'])  
    cold_start_customers = customers[~customers['customer_id'].isin(transaction_customers)]
    
    # Split cold start customers into train, validation, and test
    train_cold_start, temp_cold_start = train_test_split(cold_start_customers, test_size=0.25, random_state=42)
    val_cold_start, test_cold_start = train_test_split(temp_cold_start, test_size=0.5, random_state=42)
    
    # Merge cold-start data with train/val/test datasets
    train_data = pd.concat([train_data, train_cold_start])
    val_data = pd.concat([val_data, val_cold_start])
    test_data = pd.concat([test_data, test_cold_start])
    
    # Filter customers to only include those appearing in train/val/test sets
    train_customers = customers[customers['customer_id'].isin(train_data['customer_id'])]
    val_customers = customers[customers['customer_id'].isin(val_data['customer_id'])]
    test_customers = customers[customers['customer_id'].isin(test_data['customer_id'])]
    
    # Filter articles to only include those appearing in train/val/test sets
    train_articles = articles_with_images[articles_with_images['article_id'].isin(train_data['article_id'])]
    val_articles = articles_with_images[articles_with_images['article_id'].isin(val_data['article_id'])]
    test_articles = articles_with_images[articles_with_images['article_id'].isin(test_data['article_id'])]



        # ✅ Save preprocessed data locally
    with open(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl"), "wb") as f:
        pickle.dump(train_data, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "val_data.pkl"), "wb") as f:
        pickle.dump(val_data, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "test_data.pkl"), "wb") as f:
        pickle.dump(test_data, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "train_customers.pkl"), "wb") as f:
        pickle.dump(train_customers, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "val_customers.pkl"), "wb") as f:
        pickle.dump(val_customers, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "test_customers.pkl"), "wb") as f:
        pickle.dump(test_customers, f)


    with open(os.path.join(DATA_SPLITTING_DIR, "train_articles.pkl"), "wb") as f:
        pickle.dump(train_articles, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "val_articles.pkl"), "wb") as f:
        pickle.dump(val_articles, f)

    with open(os.path.join(DATA_SPLITTING_DIR, "test_articles.pkl"), "wb") as f:
        pickle.dump(test_articles, f)
    

    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(DATA_SPLITTING_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(DATA_SPLITTING_DIR):
            zipf.write(os.path.join(DATA_SPLITTING_DIR, file), arcname=file)

    print(f"✅ data splitting completed! Saved as {DATA_SPLITTING_ZIP_FILE}")
# Out:
# ✅ train_data data already exists. Loading...
# ✅ SPLIT data loaded successfully!

# %%
### Step 9: Create the final feature matrices

def filter_and_align_embeddings(data, articles, customers):
    """ Ensures that price, text, image, and customer embeddings are aligned properly. """
    
    # 1️⃣ **Filter transactions to unique article IDs**
    valid_articles = articles[articles['article_id'].isin(data['article_id'])].reset_index(drop=True)

    # 2️⃣ **Filter customers to only those appearing in `train_data`**
    valid_customers = customers[customers['customer_id'].isin(data['customer_id'])].reset_index(drop=True)

    # 3️⃣ **Extract price values matching valid articles**
    price_values = (
        data.drop_duplicates(subset=["article_id"])  # Deduplicate articles
        .set_index("article_id")
        .loc[valid_articles["article_id"], "price"]
        .values.reshape(-1, 1).astype(np.float32)
    )

    # 4️⃣ **Ensure correct embedding shapes**
    text_embeds = np.array(text_embeddings[valid_articles.index].tolist(), dtype=np.float32)
    image_embeds = np.array(image_embeddings[valid_articles.index].tolist(), dtype=np.float32)
    customer_embeds = np.array(customer_embeddings[valid_customers.index].tolist(), dtype=np.float32)

    # 5️⃣ **Ensure all features have the same row count**
    min_rows = min(len(price_values), len(text_embeds), len(image_embeds), len(customer_embeds))
    return np.hstack([
        price_values[:min_rows],  
        text_embeds[:min_rows],  
        image_embeds[:min_rows],  
        customer_embeds[:min_rows]
    ])

# %%
# # ✅ Define file paths for saving preprocessed data
# FEATURES_DIR = "/kaggle/working/features"
# FEATURES_ZIP_FILE = "/kaggle/working/features.zip"  # Final zipped archive

# # ✅ Create the directory if it doesn't exist
# os.makedirs(FEATURES_DIR, exist_ok=True)

# ✅ Correct path (inside `/kaggle/input/preprocessed-data/`)
FEATURES_DIR = "/kaggle/input/features"

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(FEATURES_DIR, "train_features.pkl")):
    print("✅ features are already exists. Loading...")

    # Load extracted data
    with open(os.path.join(FEATURES_DIR, "train_features.pkl"), "rb") as f:
        train_features = pickle.load(f)

    with open(os.path.join(FEATURES_DIR, "val_features.pkl"), "rb") as f:
        val_features = pickle.load(f)

    with open(os.path.join(FEATURES_DIR, "test_features.pkl"), "rb") as f:
        test_features = pickle.load(f)

    print("✅ features loaded successfully!")

else :

    print("⚡ Extracting features for the first time...")
    # ✅ Align and stack features properly
    train_features = filter_and_align_embeddings(train_data, train_articles, train_customers)
    val_features = filter_and_align_embeddings(val_data, val_articles, val_customers)
    test_features = filter_and_align_embeddings(test_data, test_articles, test_customers)


         # ✅ Save preprocessed data locally
    with open(os.path.join(FEATURES_DIR, "train_features.pkl"), "wb") as f:
        pickle.dump(train_features, f)

    with open(os.path.join(FEATURES_DIR, "val_features.pkl"), "wb") as f:
        pickle.dump(val_features, f)

    with open(os.path.join(FEATURES_DIR, "test_features.pkl"), "wb") as f:
        pickle.dump(test_features, f)


    # ✅ Create a ZIP archive containing all preprocessed files
    with zipfile.ZipFile(FEATURES_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(FEATURES_DIR):
            zipf.write(os.path.join(FEATURES_DIR, file), arcname=file)

    print(f"✅ features completed! Saved as {FEATURES_ZIP_FILE}")
# Out:
# ✅ features are already exists. Loading...
# ✅ features loaded successfully!

# %%
# ✅ Extract ZIP only if the preprocessed files don't already exist
if os.path.exists(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl")):
    print("✅ train_data data already exists. Loading...")

    # ✅ Load existing preprocessed files
    def load_pkl(filepath):
        with open(filepath, "rb") as f:
            return pickle.load(f)
    
    # train_data = load_pkl(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl"))
    train_customers = load_pkl(os.path.join(DATA_SPLITTING_DIR, "train_customers.pkl"))
    train_articles = load_pkl(os.path.join(DATA_SPLITTING_DIR, "train_articles.pkl"))
    
    print("✅ Splitted data loaded. Updating positive indices...")
# Out:
# ✅ train_data data already exists. Loading...
# ✅ Splitted data loaded. Updating positive indices...

# %%
# ✅ Check if positive indices already exist in datasets
positive_indices_exist = (
    "positive_indices" in train_articles.columns and 
    "positive_indices" in train_customers.columns and
    "customer_to_product_positive_indices" in train_customers.columns
)

# %%
if positive_indices_exist:
    print("✅ Positive indices already exist. Skipping computation!")
else:
    print("⚡ Positive indices not found! Generating...")
    
    # ✅ Convert only if it's a PyTorch tensor, otherwise leave it as is
    if isinstance(text_embeddings, torch.Tensor):
        text_embeddings = text_embeddings.to(torch.float32).cpu().numpy()
        
    if isinstance(image_embeddings, torch.Tensor):
        image_embeddings = image_embeddings.to(torch.float32).cpu().numpy()
    
    # ✅ Now safely concatenate
    article_embedding_matrix = torch.tensor(np.hstack([text_embeddings, image_embeddings]), dtype=torch.float32).to(device)

    customer_embedding_matrix = torch.tensor(customer_embeddings.to(torch.float32)).to(device)

    
    # ✅ Create Index Mappings
    article_to_index = {article_id: idx for idx, article_id in enumerate(train_articles['article_id'])}
    customer_to_index = {customer_id: idx for idx, customer_id in enumerate(train_customers['customer_id'])}
    
    # ✅ Define function with GPU support
    def get_positive_indices(idx, product_group_name, colour_group_code, entity_id, embedding_matrix, entity_type):
        if entity_type == "customer":
            # Retrieve co-purchased articles for the customer
            purchased_articles = train_data[train_data['customer_id'] == entity_id]['article_id'].unique()
            return [article_to_index[aid] for aid in purchased_articles if aid in article_to_index][:10]
    
        elif entity_type == "product":
            # Find articles with the same product group and colour group
            group_indices = train_articles[
                (train_articles['product_group_name'] == product_group_name) &
                (train_articles['colour_group_code'] == colour_group_code)
            ].index.tolist()
    
            return group_indices[:10]  # Select top 10 based on group and color (for now)
    
        elif entity_type == "customer_to_product":
            # Retrieve customers who purchased a given product
            purchasing_customers = train_data[train_data['article_id'] == entity_id]['customer_id'].unique()
            return [customer_to_index[cid] for cid in purchasing_customers if cid in customer_to_index][:10]
    
        return []
    
    # ✅ Move `apply` operations to GPU-compatible format (Avoid slow `apply`)
    # Processing in batches instead of iterating over rows (vectorized computation)
    
    # ✅ **Process Articles**
    articles_product_ids = train_articles['article_id'].values
    product_positive_indices = [
        get_positive_indices(idx, row['product_group_name'], row['colour_group_code'], row['article_id'], article_embedding_matrix, "product")
        for idx, row in train_articles.iterrows()
    ]
    train_articles['positive_indices'] = product_positive_indices
    print("Process Articles done")
    
    # ✅ **Process Customers**
    customer_positive_indices = [
        get_positive_indices(idx, None, None, row['customer_id'], customer_embedding_matrix, "customer")
        for idx, row in train_customers.iterrows()
    ]
    train_customers['positive_indices'] = customer_positive_indices
    print("Customers Articles done")
    # ✅ **Process Customer-to-product Relations**
    customer_to_product_positive_indices = [
        get_positive_indices(idx, None, None, row['customer_id'], customer_embedding_matrix, "customer_to_product")
        for idx, row in train_customers.iterrows()
    ]
    train_customers['customer_to_product_positive_indices'] = customer_to_product_positive_indices
    print("Customer-to-product Articles done")
    print("✅ Positive indices generation complete and moved to GPU where possible!")


    # ✅ Overwrite only modified files
    def save_pkl(data, filepath):
        with open(filepath, "wb") as f:
            pickle.dump(data, f)
    
    # save_pkl(train_data, os.path.join(DATA_SPLITTING_DIR, "train_data.pkl"))
    save_pkl(train_customers, os.path.join(DATA_SPLITTING_DIR, "train_customers.pkl"))
    save_pkl(train_articles, os.path.join(DATA_SPLITTING_DIR, "train_articles.pkl"))
    
    # ✅ Update ZIP without deleting existing files
    with zipfile.ZipFile(DATA_SPLITTING_ZIP_FILE, 'a') as zipf:
        # zipf.write(os.path.join(DATA_SPLITTING_DIR, "train_data.pkl"), arcname="train_data.pkl")
        zipf.write(os.path.join(DATA_SPLITTING_DIR, "train_customers.pkl"), arcname="train_customers.pkl")
        zipf.write(os.path.join(DATA_SPLITTING_DIR, "train_articles.pkl"), arcname="train_articles.pkl")
    
    print(f"✅ Updated data saved and zipped at {DATA_SPLITTING_ZIP_FILE}")
# Out:
# ✅ Positive indices already exist. Skipping computation!

# %%
# Check if CUDA is available
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ✅ Convert lists to GPU tensors
total_products = len(train_articles)
total_customers = len(train_customers)

product_indices = torch.arange(total_products, device=device)
customer_indices = torch.arange(total_customers, device=device)

# ✅ **GPU-Accelerated Hard Negative Sampling**
def generate_hard_negatives(total_items, positive_sets, entity_type, num_samples=10):
    """
    Implements HARD NEGATIVE SAMPLING (as in C-STAR).
    Selects items that are similar to positives but were NOT co-purchased.

    ✅ Now uses **GPU acceleration** for efficiency 🚀
    """
    negative_indices = torch.full((total_items, num_samples), -1, dtype=torch.long, device=device)  # Pre-allocate

    # ✅ Convert `positive_sets` to **tensors** for GPU processing
    exclusions = {i: torch.tensor(list(positive_sets.iloc[i]), device=device) if i < len(positive_sets) else torch.tensor([], device=device) for i in range(total_items)}

    for i in range(total_items):
        if entity_type == "product":
            valid_negatives = product_indices[~torch.isin(product_indices, exclusions[i])]
        elif entity_type == "customer":
            valid_negatives = customer_indices[~torch.isin(customer_indices, exclusions[i])]
        elif entity_type == "customer_to_product":
            valid_negatives = customer_indices[~torch.isin(customer_indices, exclusions[i])]

        if len(valid_negatives) > 0:
            sampled_negatives = valid_negatives[:min(num_samples, len(valid_negatives))]
            negative_indices[i, :len(sampled_negatives)] = sampled_negatives  # Assign sampled negatives

    return negative_indices.cpu().numpy()  # Move back to CPU **after** computation

# ✅ **Generate Negative Indices for Products (GPU-Accelerated)**
positive_sets_products = train_articles['positive_indices'].apply(set)
train_articles['negative_indices'] = list(generate_hard_negatives(total_products, positive_sets_products, entity_type="product"))

# ✅ **Generate Negative Indices for Customers (GPU-Accelerated)**
positive_sets_customers = train_customers['positive_indices'].apply(set)
train_customers['negative_indices'] = list(generate_hard_negatives(total_customers, positive_sets_customers, entity_type="customer"))

# ✅ **Generate Negative Indices for Product-to-Customer (GPU-Accelerated)**
positive_sets_customer_to_product = train_customers['customer_to_product_positive_indices'].apply(set)
train_customers['negative_customer_to_product_indices'] = list(generate_hard_negatives(total_customers, positive_sets_customer_to_product, entity_type="customer_to_product"))

print("✅ Hard negative sampling moved to GPU for **faster execution** 🚀")
# Out:
# ✅ Hard negative sampling moved to GPU for **faster execution** 🚀

# %%
class GCNLayer(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(GCNLayer, self).__init__()
        self.linear = nn.Linear(input_dim, output_dim)

    def forward(self, features, edge_index):
        row, col = edge_index

        # ✅ Validate edge indices before using them
        num_nodes = features.size(0)  # Total number of nodes in the graph
        if row.max() >= num_nodes or col.max() >= num_nodes:
            print(f"🚨 Error: edge_index contains out-of-bounds indices! row.max={row.max()}, col.max={col.max()}, num_nodes={num_nodes}")

            # ✅ Filter out invalid edges
            mask = (row < num_nodes) & (col < num_nodes)  # Keep only valid indices
            row, col = row[mask], col[mask]
            edge_index = torch.stack([row, col], dim=0)

        # ✅ Compute node degrees
        degree = torch.bincount(row, minlength=features.size(0)).float() + 1e-6
        norm = 1.0 / torch.sqrt(degree[row] * degree[col])

        # Aggregate the features
        agg_features = torch.zeros_like(features)
        # agg_features.index_add_(0, row, features[col] * norm.view(-1, 1))
        agg_features = agg_features.index_add(0, row, features[col] * norm.view(-1, 1))  # ✅ Out-of-place


        return F.relu(self.linear(agg_features))

# %%
# class C_STAR(nn.Module):
#     def __init__(self, input_dim, embedding_dim, num_layers, dropout):
#         super(C_STAR, self).__init__()

#         self.embedding_layer = nn.Sequential(
#             nn.Linear(input_dim, embedding_dim),
#             nn.ReLU()
#         )

#         self.gcn_layers = nn.ModuleList([GCNLayer(embedding_dim, embedding_dim) for _ in range(num_layers)])
#         self.dropout = dropout
#         self.reference_embedding = nn.Parameter(torch.randn(embedding_dim))  # Randomly initialized reference

#     def forward(self, features, customer_to_product_edge_index, product_to_product_edge_index):
#         embeddings = self.embedding_layer(features)
#         embeddings = F.dropout(embeddings, p=self.dropout, training=self.training)

#         # Apply each GCN layer separately for different edge types
#         for gcn_layer in self.gcn_layers:
#             embeddings_product_to_product = gcn_layer(embeddings, product_to_product_edge_index)
#             embeddings_customer_to_product = gcn_layer(embeddings, customer_to_product_edge_index)
#             # embeddings_customer_to_customer = gcn_layer(embeddings, customer_to_customer_edge_index)

#             # Combine embeddings (adjust weights as needed)
#             # embeddings = (embeddings_product_to_product + embeddings_customer_to_product + embeddings_customer_to_customer) / 3
#             embeddings = (embeddings_product_to_product + embeddings_customer_to_product) / 3
#             embeddings = F.dropout(embeddings, p=self.dropout, training=self.training)

#         return embeddings


class C_STAR(nn.Module):
    def __init__(self, input_dim, embedding_dim, num_layers, dropout):
        super(C_STAR, self).__init__()

        self.embedding_layer = nn.Sequential(
            nn.Linear(input_dim, embedding_dim, dtype=torch.float32),  # Ensure float32
            nn.ReLU()
        )

        self.gcn_layers = nn.ModuleList([GCNLayer(embedding_dim, embedding_dim) for _ in range(num_layers)])
        self.dropout = dropout
        self.reference_embedding = nn.Parameter(torch.randn(embedding_dim, dtype=torch.float32))  # Ensure float32

    def forward(self, features, customer_to_product_edge_index, product_to_product_edge_index):
        embeddings = self.embedding_layer(features.to(torch.float32))  # Convert input to float32
        embeddings = F.dropout(embeddings, p=self.dropout, training=self.training)

        for gcn_layer in self.gcn_layers:
            embeddings_product_to_product = gcn_layer(embeddings, product_to_product_edge_index)
            embeddings_customer_to_product = gcn_layer(embeddings, customer_to_product_edge_index)

            embeddings = (embeddings_product_to_product + embeddings_customer_to_product) / 3
            embeddings = F.dropout(embeddings, p=self.dropout, training=self.training)

        return embeddings

# %%
def inter_trajectory_loss(embeddings, reference_embedding):
    """
    Computes the inter-trajectory loss using Sliced Wasserstein Distance.
    """
    return sliced_wasserstein_distance(embeddings, reference_embedding)



def intra_trajectory_loss(embeddings, positive_indices, negative_indices, batch_mapping):
    """
    Computes the intra-trajectory loss.
    Ensures positive & negative indices are properly mapped and converted to tensors.
    """
    # ✅ Convert lists to tensors before using `.view(-1)`
    positive_indices = torch.tensor(positive_indices, dtype=torch.long, device=embeddings.device)
    negative_indices = torch.tensor(negative_indices, dtype=torch.long, device=embeddings.device)

    # ✅ Map to local batch indices (if needed)
    positive_indices = torch.tensor(
        [batch_mapping.get(idx, -1) for idx in positive_indices.tolist()],
        dtype=torch.long, device=embeddings.device
    )
    negative_indices = torch.tensor(
        [batch_mapping.get(idx, -1) for idx in negative_indices.tolist()],
        dtype=torch.long, device=embeddings.device
    )

    # ✅ Filter valid indices
    positive_indices = positive_indices[positive_indices >= 0]
    negative_indices = negative_indices[negative_indices >= 0]

    # ✅ Return 0 loss if no valid pairs exist
    if positive_indices.numel() == 0 or negative_indices.numel() == 0:
        return torch.tensor(0.0, requires_grad=True, device=embeddings.device)

    # ✅ Compute cosine similarity for loss
    positive_scores = torch.einsum('ij,ij->i', embeddings[positive_indices], embeddings[positive_indices])
    negative_scores = torch.einsum('ij,ij->i', embeddings[negative_indices], embeddings[negative_indices])

    # ✅ Adaptive margin based on embedding variance
    margin = 1.0 + 0.1 * torch.std(embeddings)
    loss = F.relu(negative_scores + margin - positive_scores).mean()
    
    return loss

# %%
def compute_loss(embeddings, article_idx, pos_indices, neg_indices, model, edge_type):
    # ✅ Debug print before accessing embeddings
    num_embeddings = embeddings.size(0)  # Get the actual embedding size
    if article_idx >= num_embeddings:
        # print(f"🚨 ERROR: article_idx={article_idx} is out of bounds (max index {num_embeddings - 1})")
        return torch.tensor(0.0, device=embeddings.device)  # Return zero loss to prevent crash

    inter_loss = inter_trajectory_loss(embeddings[article_idx].unsqueeze(0), model.reference_embedding)
    intra_loss = intra_trajectory_loss(embeddings, pos_indices, neg_indices, {})
    return inter_loss + intra_loss

# %%
# # ✅ Define directory and file paths
# GRAPH_DIR = "/kaggle/working/graph_data"
# GRAPH_ZIP_FILE = "/kaggle/working/graph_data.zip"

# # ✅ Create the directory if it doesn't exist
# os.makedirs(GRAPH_DIR, exist_ok=True)

GRAPH_DIR = "/kaggle/input/graph-data"

# %%
# ✅ Check if precomputed ZIP file exists
if os.path.exists(os.path.join(GRAPH_DIR, "pr_graph.pkl")):
    print("✅ PR graph is already exists. Loading...")

    # ✅ Load PR-Graph
    with open(os.path.join(GRAPH_DIR, "pr_graph.pkl"), "rb") as f:
        PR_graph = pickle.load(f)

    # ✅ Load Edge Index Tensors
    # edge_index = torch.load(os.path.join(GRAPH_DIR, "edge_index.pt"))
    product_to_product_edge_index = torch.load(os.path.join(GRAPH_DIR, "product_to_product_edge.pt"))
    # customer_to_customer_edge_index = torch.load(os.path.join(GRAPH_DIR, "customer_to_customer_edge_index.pt"))
    customer_to_product_edge_index = torch.load(os.path.join(GRAPH_DIR, "customer_to_product_edge.pt"))

    print("✅ PR-Graph and Edge Index loaded successfully!")

else:
    # print("⚡ Recomputing PR-Graph and Edge Index...")

    # # Construct the PR-Graph (Product-Relation Graph) based on co-purchase pairs
    # PR_graph = nx.Graph()

    # # ✅ Step 1: Add customer nodes with embeddings
    # for customer_id in train_customers['customer_id']:
    #     PR_graph.add_node(customer_id)

    # # ✅ Step 2: Add product nodes (without redundant iteration)
    # for article_id in train_articles['article_id']:
    #     PR_graph.add_node(article_id)  # No embedding needed for products

    # # ✅ Step 3: Add customer-to-product edges based on purchase history
    # customer_article_pairs = train_data[['customer_id', 'article_id']].values
    # PR_graph.add_edges_from(customer_article_pairs)
    
    # # ✅ Step 4: Efficiently Add Customer-to-Customer Similarity Edges using SWD
    # # customer_ids = list(train_customers['customer_id'])  # List of customer IDs for mapping

    # # # Convert embeddings to tensor
    # # customer_embeddings_tensor = torch.tensor(customer_embeddings, dtype=torch.float32)
    
    # # # Compute **pairwise Sliced Wasserstein Distance (SWD)**
    # # for i in range(len(customer_embeddings)):
    # #     swd_distances = []
    # #     for j in range(i + 1, len(customer_embeddings)):
    # #         swd_dist = sliced_wasserstein_distance(
    # #             customer_embeddings_tensor[i], customer_embeddings_tensor[j]
    # #         )
    # #         swd_distances.append((customer_ids[i], customer_ids[j], swd_dist.item()))
    
    # #     # ✅ Only add edges for customers with SWD < threshold (efficient filtering)
    # #     for u, v, dist in swd_distances:
    # #         if dist < 0.5:  # ✅ Adjust the threshold as needed
    # #             PR_graph.add_edge(u, v)

    # # ✅ Step 4: Efficiently Add Customer-to-Customer Similarity Edges using SWD
    # customer_ids = list(train_customers['customer_id'])  # List of customer IDs for mapping
    
    # # ✅ Convert bfloat16 to float32 before using NumPy
    # train_customer_embeddings = np.array(customer_embeddings.to(torch.float32))[train_customers.index]  
    
    # # ✅ Convert to tensor properly
    # customer_embeddings_tensor = torch.tensor(train_customer_embeddings, dtype=torch.float32).to(device)
    
    # # ✅ Ensure correct shape
    # if customer_embeddings_tensor.dim() == 1:
    #     customer_embeddings_tensor = customer_embeddings_tensor.unsqueeze(1)
    
    # # ✅ Compute **pairwise Sliced Wasserstein Distance (SWD)**
    # for i in range(len(train_customer_embeddings)):
    #     swd_distances = []
    #     for j in range(i + 1, len(train_customer_embeddings)):
    #         swd_dist = sliced_wasserstein_distance(
    #             customer_embeddings_tensor[i].unsqueeze(0), customer_embeddings_tensor[j].unsqueeze(0)
    #         )
    #         swd_distances.append((customer_ids[i], customer_ids[j], swd_dist.item()))
    
    #     # ✅ Only add edges for customers with SWD < threshold (efficient filtering)
    #     for u, v, dist in swd_distances:
    #         if dist < 0.5:  # ✅ Adjust the threshold as needed
    #             PR_graph.add_edge(u, v)

    # # ✅ Step 5: Add product-to-product co-purchase edges (but avoid redundant loops)
    # co_purchase_pairs = train_data.groupby('customer_id')['article_id'].apply(list)
    # for articles_list in co_purchase_pairs:
    #     for i in range(len(articles_list)):
    #         for j in range(i + 1, len(articles_list)):
    #             PR_graph.add_edge(articles_list[i], articles_list[j])

    # # ✅ Done! Your PR-Graph is now optimized 🚀
    # print(f"📌 PR-Graph Constructed: {PR_graph.number_of_nodes()} nodes, {PR_graph.number_of_edges()} edges")

    # # Step 5: Map article IDs and customer IDs to indices for use in edge_index
    # # article_to_index = {article_id: idx for idx, article_id in enumerate(PR_graph.nodes)}
    # # customer_to_index = {customer_id: idx for idx, customer_id in enumerate(train_customers['customer_id'])}

    # # ✅ Create separate article and customer indices
    # article_nodes = train_articles['article_id'].tolist()
    # customer_nodes = train_customers['customer_id'].tolist()
    
    # # ✅ Index only articles separately
    # article_to_index = {article_id: idx for idx, article_id in enumerate(article_nodes)}
    
    # # ✅ Index only customers separately
    # customer_to_index = {customer_id: idx for idx, customer_id in enumerate(customer_nodes)}


    # # Step 6: Convert edge list to tensor (edge_index)
    # edges_indices = []
    
    # # Separate the edges into product-to-product, customer-to-product, and customer-to-customer
    # product_to_product_edges = []
    # customer_to_product_edges = []
    # customer_to_customer_edges = []
    
    # # Iterate through the PR graph edges and classify the edges based on node types
    # for u, v in PR_graph.edges():
    #     if u in article_to_index and v in article_to_index:
    #         # Product-to-product edge
    #         product_to_product_edges.append((article_to_index[u], article_to_index[v]))
    #         edges_indices.append((article_to_index[u], article_to_index[v]))
    #     elif u in customer_to_index and v in article_to_index:
    #         # Customer-to-product edge
    #         customer_to_product_edges.append((customer_to_index[u], article_to_index[v]))
    #         edges_indices.append((customer_to_index[u], article_to_index[v]))
    #     elif u in customer_to_index and v in customer_to_index:
    #         # Customer-to-customer edge
    #         customer_to_customer_edges.append((customer_to_index[u], customer_to_index[v]))
    #         edges_indices.append((customer_to_index[u], customer_to_index[v]))
    
    # # Convert edge list to tensor (edge_index) for all edges
    # edge_index = torch.tensor(edges_indices, dtype=torch.long).t().contiguous()
    
    # # Step 7: Add self-loops (common in graph-based models)
    # edge_index, _ = add_self_loops(edge_index, num_nodes=len(PR_graph.nodes))
    
    # # Ensure edge_index dimensions are correct
    # assert edge_index.size(0) == 2, "Edge index should have two rows: source and target nodes."
    # assert edge_index.size(1) > 0, "Edge index should have at least one edge."
    
    # print("PR Graph successfully constructed!")
    
    # # Now, you have separate edge indices for each type of edge.
    # product_to_product_edge_index = torch.tensor(product_to_product_edges, dtype=torch.long).t().contiguous()
    # customer_to_product_edge_index = torch.tensor(customer_to_product_edges, dtype=torch.long).t().contiguous()
    # customer_to_customer_edge_index = torch.tensor(customer_to_customer_edges, dtype=torch.long).t().contiguous()
    
    # # These edge indices are now available for further processing.
    
    # print(edge_index.shape) 


    
    print("⚡ Constructing PR-Graph and Edge Index...")
    
    # ✅ Create separate indices for articles and customers
    article_nodes = train_articles['article_id'].tolist()
    customer_nodes = train_customers['customer_id'].tolist()
    
    # ✅ Create lookup dictionaries for fast access
    article_to_index = {article_id: idx for idx, article_id in enumerate(article_nodes)}
    customer_to_index = {customer_id: idx for idx, customer_id in enumerate(customer_nodes)}


    train_data = train_data.dropna(subset=['customer_id', 'article_id'])

    
    # ✅ Step 1: Construct Edge Lists Efficiently (Batch Processing)
    customer_to_product_edges = np.array([
        (customer_to_index.get(u, -1), article_to_index.get(v, -1))
        for u, v in train_data[['customer_id', 'article_id']].values
    ], dtype=np.int64)

    # Remove invalid edges
    customer_to_product_edges = customer_to_product_edges[(customer_to_product_edges[:, 0] != -1) & (customer_to_product_edges[:, 1] != -1)]


    print("c-p done")
    product_to_product_edges = []
    co_purchase_pairs = train_data.groupby('customer_id')['article_id'].apply(list)
    for articles_list in co_purchase_pairs:
        product_to_product_edges.extend([(article_to_index[articles_list[i]], article_to_index[articles_list[j]]) 
                                         for i in range(len(articles_list)) for j in range(i + 1, len(articles_list))])
    print("p-p done")
    # ✅ Step 2: Optimize Customer-to-Customer Similarity using FAISS
    
    # ✅ Convert PyTorch Tensor to float32 before using FAISS
    # ✅ Ensure embeddings are in float32 NumPy format before FAISS
    # customer_embeddings_np = customer_embeddings.to(torch.float32).cpu().numpy()
    
    # # ✅ Initialize FAISS Index
    # index = faiss.IndexFlatL2(customer_embeddings_np.shape[1])  
    # index.add(customer_embeddings_np)
    
    # k = 10  # Find top 10 nearest neighbors
    
    # # ✅ Convert embeddings before calling FAISS search
    # D, I = index.search(customer_embeddings_np, k)


    # # ✅ Ensure FAISS index outputs are valid before using them
    # customer_to_customer_edges = np.array([
    #     (customer_to_index[customer_nodes[i]], customer_to_index[customer_nodes[I[i][j]]]) 
    #     for i in range(len(I)) 
    #     for j in range(1, min(k, len(I[i])))  # Ensure j does not exceed available neighbors
    #     if D[i][j] < 0.5  # Apply distance threshold
    # ], dtype=np.int64)

    
    # print("c-c done")
    # ✅ Step 3: Convert Edge Lists to PyTorch Tensors
    customer_to_product_edges = torch.tensor(customer_to_product_edges, dtype=torch.long).t().contiguous()
    product_to_product_edges = torch.tensor(product_to_product_edges, dtype=torch.long).t().contiguous()
    # customer_to_customer_edges = torch.tensor(customer_to_customer_edges, dtype=torch.long).t().contiguous()
    
     # ✅ Step 4: Construct the Graph Using DGL (Preserving Separate Edge Types)
    
    # ✅ Create PyG Heterogeneous Graph
    graph = HeteroData()

    # ✅ Ensure the edge index is correctly formatted
    if isinstance(customer_to_product_edges, torch.Tensor):
        graph['customer', 'buys', 'product'].edge_index = customer_to_product_edges  # Already a tensor
        graph['product', 'co_purchased_with', 'product'].edge_index = product_to_product_edges
    else:
        graph['customer', 'buys', 'product'].edge_index = torch.stack(customer_to_product_edges, dim=0)  # Convert if needed
        graph['product', 'co_purchased_with', 'product'].edge_index = torch.stack(product_to_product_edges, dim=0)
    
    # ✅ Add Edges for Customer-Product Interactions
    # graph['customer', 'buys', 'product'].edge_index = torch.stack(customer_to_product_edges, dim=0)
    
    # ✅ Add Edges for Product-to-Product Co-Purchase
    # graph['product', 'co_purchased_with', 'product'].edge_index = torch.stack(product_to_product_edges, dim=0)
    
    # ✅ Add Edges for Customer-to-Customer Similarity
    # graph['customer', 'similar_to', 'customer'].edge_index = torch.stack(customer_to_customer_edges, dim=0)
    
    # ✅ Add Self-Loops (for better message passing in GNNs)
    # graph['customer', 'similar_to', 'customer'].edge_index = add_self_loops(graph['customer', 'similar_to', 'customer'].edge_index)[0]
    # graph['product', 'co_purchased_with', 'product'].edge_index = add_self_loops(graph['product', 'co_purchased_with', 'product'].edge_index)[0]
    # graph['customer', 'buys', 'product'].edge_index = add_self_loops(graph['customer', 'buys', 'product'].edge_index)[0]


    if 'edge_index' in graph['product', 'co_purchased_with', 'product']:
        graph['product', 'co_purchased_with', 'product'].edge_index = add_self_loops(graph['product', 'co_purchased_with', 'product'].edge_index)[0]
    
    if 'edge_index' in graph['customer', 'buys', 'product']:
        graph['customer', 'buys', 'product'].edge_index = add_self_loops(graph['customer', 'buys', 'product'].edge_index)[0]

    print(graph)

     # ✅ Save PR-Graph & Edge Index Locally
    with open(os.path.join(GRAPH_DIR, "pr_graph.pkl"), "wb") as f:
        pickle.dump(graph, f)

    # torch.save(edge_index, os.path.join(GRAPH_DIR, "edge_index.pt"))
    torch.save(product_to_product_edges, os.path.join(GRAPH_DIR, "product_to_product_edge.pt"))
    torch.save(customer_to_product_edges, os.path.join(GRAPH_DIR, "customer_to_product_edge.pt"))
    # torch.save(customer_to_customer_edge_index, os.path.join(GRAPH_DIR, "customer_to_customer_edge_index.pt"))

    # ✅ Create ZIP Archive for Future Use
    with zipfile.ZipFile(GRAPH_ZIP_FILE, 'w') as zipf:
        for file in os.listdir(GRAPH_DIR):
            zipf.write(os.path.join(GRAPH_DIR, file), arcname=file)

    print(f"✅ PR-Graph and Edge Index processing completed! Saved as {GRAPH_ZIP_FILE}")
# Out:
# ⚡ Constructing PR-Graph and Edge Index...
# c-p done
# p-p done
# HeteroData(
#   (customer, buys, product)={ edge_index=[2, 311842] },
#   (product, co_purchased_with, product)={ edge_index=[2, 77925] }
# )
# ✅ PR-Graph and Edge Index processing completed! Saved as /kaggle/working/graph_data.zip

# %%
# ✅ Define checkpoint file path
CHECKPOINT_FILE = "/kaggle/working/checkpoint.pth"

# ✅ Save model checkpoint
def save_checkpoint(model, optimizer, epoch, filename=CHECKPOINT_FILE):
    checkpoint = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()
    }
    torch.save(checkpoint, filename)
    print(f"✅ Model checkpoint saved at epoch {epoch}")

# ✅ Load model checkpoint
def load_checkpoint(filename, model, optimizer=None):
    if os.path.exists(filename):
        print("✅ Loading checkpoint...")
        checkpoint = torch.load(filename, map_location=device)
        model.load_state_dict(checkpoint['model_state_dict'])
        if optimizer:
            optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        print(f"✅ Resuming training from epoch {checkpoint['epoch'] + 1}")
        return checkpoint['epoch'] + 1  # Resume from the next epoch
    else:
        print("⚡ No checkpoint found. Starting from scratch.")
        return 0  # Start from epoch 0 if no checkpoint exists

# %%
# ✅ Use a smaller dataset for quick testing
train_data = train_data.sample(n=10000, random_state=42)  
val_data = val_data.sample(n=2000, random_state=42)
test_data = train_data.sample(n=2000, random_state=42)

# %%
def train_full_batch_with_early_stopping(model, optimizer, num_epochs, patience, start_epoch):
    best_val_loss = float('inf')
    patience_counter = 0
    best_model_state = None

    # ✅ Move model & data to GPU
    model = model.to(device)

    train_features_tensor = torch.tensor(train_features, dtype=dtype).to(device)
    val_features_tensor = torch.tensor(val_features, dtype=dtype).to(device)

    # ✅ Move Edge Indices to GPU
    # product_to_product_edge_index_tensor = product_to_product_edges.to(device)
    # customer_to_product_edge_index_tensor = customer_to_product_edges.to(device)
    # customer_to_customer_edge_index_tensor = customer_to_customer_edge_index.to(device)

    customer_to_product_edge_index_tensor = customer_to_product_edges.to(torch.long).to(device)
    product_to_product_edge_index_tensor = product_to_product_edges.to(torch.long).to(device)


    with torch.no_grad():
        # initial_embeddings = model(train_features_tensor, customer_to_product_edge_index_tensor, product_to_product_edge_index_tensor, customer_to_customer_edge_index_tensor)
        # initial_swd = sliced_wasserstein_distance(initial_embeddings, model.reference_embedding).item()
        # print(f"✅ Initial SWD: {initial_swd:.4f}")


        initial_embeddings = model(train_features_tensor, customer_to_product_edge_index_tensor, product_to_product_edge_index_tensor)
        initial_swd = sliced_wasserstein_distance(initial_embeddings, model.reference_embedding).item()
        print(f"✅ Initial SWD: {initial_swd:.4f}")

    for epoch in range(start_epoch, num_epochs):
        model.train()
        optimizer.zero_grad()

        # ✅ Forward pass with separate edge types
        embeddings = model(train_features_tensor, customer_to_product_edge_index_tensor, product_to_product_edge_index_tensor)

        train_loss_acc = torch.zeros([], requires_grad=True, device=device)

        for _, row in train_data.iterrows():
            article_id = row["article_id"]
            customer_id = row["customer_id"]

            article_idx = article_to_index.get(article_id, -1)
            customer_idx = customer_to_index.get(customer_id, -1)

            if article_idx == -1 or customer_idx == -1:
                continue  # Skip invalid entries

            pos_indices_product = torch.tensor(row["positive_indices_product"], dtype=torch.long, device=device)
            neg_indices_product = torch.tensor(row["negative_indices_product"], dtype=torch.long, device=device)

            pos_indices_customer_product = torch.tensor(row["positive_indices_customer_product"], dtype=torch.long, device=device)
            neg_indices_customer_product = torch.tensor(row["negative_indices_customer_product"], dtype=torch.long, device=device)

            # pos_indices_customer = torch.tensor(row["positive_indices_customer"], dtype=torch.long, device=device)
            # neg_indices_customer = torch.tensor(row["negative_indices_customer"], dtype=torch.long, device=device)

            # ✅ Compute losses for each edge type
            train_loss_acc = train_loss_acc + (
                compute_loss(embeddings, article_idx, pos_indices_product, neg_indices_product, model, "product_to_product") +
                compute_loss(embeddings, customer_idx, pos_indices_customer_product, neg_indices_customer_product, model, "customer_to_product")
                # compute_loss(embeddings, customer_idx, pos_indices_customer, neg_indices_customer, model, "customer_to_customer")
            )

        # ✅ Backpropagation
        train_loss_acc.backward()
        optimizer.step()

        avg_train_loss = train_loss_acc.item() / max(len(train_data), 1)

        # ✅ Validation Phase
        model.eval()
        total_val_loss = 0.0

        with torch.no_grad():
            # val_embeddings = model(val_features_tensor, customer_to_product_edge_index_tensor, product_to_product_edge_index_tensor, customer_to_customer_edge_index_tensor)
            val_embeddings = model(val_features_tensor, customer_to_product_edge_index_tensor, product_to_product_edge_index_tensor)
            

            for _, row in val_data.iterrows():
                article_id = row["article_id"]
                customer_id = row["customer_id"]

                article_idx = article_to_index.get(article_id, -1)
                customer_idx = customer_to_index.get(customer_id, -1)

                if article_idx == -1 or customer_idx == -1:
                    continue  # Skip invalid entries

                pos_indices_product = torch.tensor(row["positive_indices_product"], dtype=torch.long, device=device)
                neg_indices_product = torch.tensor(row["negative_indices_product"], dtype=torch.long, device=device)

                pos_indices_customer_product = torch.tensor(row["positive_indices_customer_product"], dtype=torch.long, device=device)
                neg_indices_customer_product = torch.tensor(row["negative_indices_customer_product"], dtype=torch.long, device=device)

                # pos_indices_customer = torch.tensor(row["positive_indices_customer"], dtype=torch.long, device=device)
                # neg_indices_customer = torch.tensor(row["negative_indices_customer"], dtype=torch.long, device=device)

                total_val_loss = total_val_loss + (
                    compute_loss(val_embeddings, article_idx, pos_indices_product, neg_indices_product, model, "product_to_product") +
                    compute_loss(val_embeddings, customer_idx, pos_indices_customer_product, neg_indices_customer_product, model, "customer_to_product")
                    # compute_loss(val_embeddings, customer_idx, pos_indices_customer, neg_indices_customer, model, "customer_to_customer")
                )

        avg_val_loss = total_val_loss / max(len(val_data), 1)
        print(f"Epoch {epoch + 1}/{num_epochs} | Train Loss: {avg_train_loss:.4f} | Val Loss: {avg_val_loss:.4f}")

# %%
# ✅ Convert article_id and customer_id to standard strings before mapping
train_data["article_id"] = train_data["article_id"].astype(str)
train_data["customer_id"] = train_data["customer_id"].astype(str)

# ✅ Convert train_articles and train_customers positive indices into dictionaries
article_pos_indices_dict = train_articles.set_index("article_id")["positive_indices"].to_dict()
# customer_pos_indices_dict = train_customers.set_index("customer_id")["positive_indices"].to_dict()
customer_to_product_pos_indices_dict = train_customers.set_index("customer_id")["customer_to_product_positive_indices"].to_dict()

# ✅ Convert train_articles and train_customers positive indices into dictionaries
article_neg_indices_dict = train_articles.set_index("article_id")["negative_indices"].to_dict()
# customer_neg_indices_dict = train_customers.set_index("customer_id")["negative_indices"].to_dict()
customer_to_product_neg_indices_dict = train_customers.set_index("customer_id")["negative_customer_to_product_indices"].to_dict()


# ✅ Use `.apply()` instead of `.map()` to avoid "unhashable list" error
train_data["positive_indices_product"] = train_data["article_id"].apply(lambda x: article_pos_indices_dict.get(x, []))
# train_data["positive_indices_customer"] = train_data["customer_id"].apply(lambda x: customer_pos_indices_dict.get(x, []))
train_data["positive_indices_customer_product"] = train_data["customer_id"].apply(lambda x: customer_to_product_pos_indices_dict.get(x, []))


train_data["negative_indices_product"] = train_data["article_id"].apply(lambda x: article_neg_indices_dict.get(x, []))
# train_data["negative_indices_customer"] = train_data["customer_id"].apply(lambda x: customer_neg_indices_dict.get(x, []))
train_data["negative_indices_customer_product"] = train_data["customer_id"].apply(lambda x: customer_to_product_neg_indices_dict.get(x, []))

# %%
# ✅ Compute input dimensions correctly
input_dim_text = text_embeddings.shape[1]  # Text feature dimension
input_dim_numeric = 1  # 'price' is a single value per instance
input_dim_image = image_embeddings.shape[1]  # Image feature dimension
input_dim_customer = customer_embeddings.shape[1]  # Customer feature dimension

# ✅ Total input dimension
input_dim = input_dim_text + input_dim_image + input_dim_numeric + input_dim_customer

# ✅ Define Training Hyperparameters
learning_rate = 5e-3  # ✅ Slightly higher but stable
num_epochs = 2        # ✅ Just for testing if training runs
embedding_dim = 32    # ✅ Smaller embeddings reduce computation
num_layers = 2        # ✅ Fewer layers for quick runs
dropout = 0.2         # ✅ Lower dropout for faster learning
weight_decay = 1e-5   # ✅ Helps with regularization
patience = 10         # ✅ Early stopping patience
device = torch.device("cpu") 
# ✅ Initialize the C_STAR model (Now using separate edge indices)
model = C_STAR(
    input_dim=input_dim,
    embedding_dim=embedding_dim,
    num_layers=num_layers,
    dropout=dropout
).to(device)

# ✅ Choose the correct optimizer based on TPU/GPU
if torch.cuda.is_available():
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
else:
    optimizer = optim_xla.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)  # TPU Optimized

# ✅ Load checkpoint (if available)
start_epoch = load_checkpoint(CHECKPOINT_FILE, model, optimizer)

# ✅ Move feature tensors & edge indices to GPU
train_features_tensor = torch.tensor(train_features, dtype=torch.float32).to(device)
val_features_tensor = torch.tensor(val_features, dtype=torch.float32).to(device)


customer_to_product_edge_index_tensor = customer_to_product_edges.to(device)
product_to_product_edge_index_tensor = product_to_product_edges.to(device)
# customer_to_customer_edge_index_tensor = customer_to_customer_edge_index.to(device)

# ✅ Train the model with early stopping
trained_model = train_full_batch_with_early_stopping(
    model=model,
    optimizer=optimizer,
    num_epochs=num_epochs,
    patience=patience, 
    start_epoch=start_epoch
)
# Out:
# ⚡ No checkpoint found. Starting from scratch.
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=25390, col.max=25391, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=141109, col.max=25392, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=25390, col.max=25391, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=141109, col.max=25392, num_nodes=19626
# ✅ Initial SWD: 481.5652
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=25390, col.max=25391, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=141109, col.max=25392, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=25390, col.max=25391, num_nodes=19626
# 🚨 Error: edge_index contains out-of-bounds indices! row.max=141109, col.max=25392, num_nodes=19626
# 🚨 ERROR: article_idx=81648 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76461 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135145 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=113871 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121859 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76957 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24999 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72765 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21522 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100407 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=125218 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112138 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76731 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=134659 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=119911 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20052 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55010 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76115 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20064 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114493 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44737 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69985 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90353 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=122723 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=54460 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111222 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139744 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20005 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39297 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27029 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21665 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102348 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22214 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135533 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102893 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24137 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=68328 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19821 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67941 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24657 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82419 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=85402 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64820 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120731 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64660 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=45262 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=31636 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=87605 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20451 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81223 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72937 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128110 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108658 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60551 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22263 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50484 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20264 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110320 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=63631 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19945 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27535 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60563 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19919 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21584 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77543 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=96614 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21956 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=31779 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59759 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48683 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=126465 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20286 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111323 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22526 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55474 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114344 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24313 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22360 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=134581 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20230 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69663 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=83094 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86274 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77375 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42681 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=83444 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20241 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76614 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72123 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82242 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25231 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=118792 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105483 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90475 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59003 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129465 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=107310 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20556 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105253 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21068 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47567 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48785 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108603 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51611 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78002 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=131044 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35658 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74004 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22112 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108937 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=62162 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95686 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=113643 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52066 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27633 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22071 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100705 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137138 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66585 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57090 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48658 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71179 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21595 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70388 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=130960 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=122413 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93671 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20850 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21489 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=33153 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39587 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22570 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=119844 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86748 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66669 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49363 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102777 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35095 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84786 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25390 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=28514 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21838 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34881 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21871 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74839 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=138547 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=73329 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70714 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43707 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44956 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23381 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=96407 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=28920 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=33191 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71392 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22220 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88168 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22752 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69003 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47435 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=45681 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110646 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120974 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92391 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84212 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48730 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23997 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55780 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=106003 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21821 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=83600 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88414 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=26054 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36506 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=133665 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71724 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21928 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36892 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61880 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=103717 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81651 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25285 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=138710 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60907 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23176 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44384 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51426 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20199 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=37455 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22587 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=94816 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=103309 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50103 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=109645 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20865 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82932 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66140 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80999 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72184 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21166 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111996 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95640 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23467 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23143 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140222 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24493 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24725 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47120 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123485 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49162 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64734 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24189 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93438 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95393 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72135 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70395 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=117703 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20384 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22600 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97448 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70973 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70254 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58298 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=62220 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39601 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=75580 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=130738 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111915 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20327 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=107670 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52269 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=113382 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=124147 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24890 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27987 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61428 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123957 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72574 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21735 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34050 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67562 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140069 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48070 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32472 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105301 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=30601 is out of bounds (max index 19625)
# <ipython-input-40-9b3d68b2aa37>:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   positive_indices = torch.tensor(positive_indices, dtype=torch.long, device=embeddings.device)
# <ipython-input-40-9b3d68b2aa37>:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   negative_indices = torch.tensor(negative_indices, dtype=torch.long, device=embeddings.device)
# 🚨 ERROR: article_idx=92353 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=131231 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82792 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22283 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=115696 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140906 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=109657 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48630 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93845 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90660 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89768 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67130 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92997 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21138 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=125766 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=122720 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120366 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22582 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137946 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=101044 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=107011 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=136757 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58763 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20691 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71618 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61328 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32571 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47923 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135345 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20508 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22737 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89771 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23833 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91697 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57668 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104816 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21038 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36714 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22738 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111311 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23578 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74599 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21852 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80268 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21743 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22723 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104417 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39520 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132827 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=85279 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19923 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140659 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116820 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=136677 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53846 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=30116 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67221 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42901 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98899 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93444 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23200 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93545 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139977 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60705 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71297 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114087 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111772 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91608 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22109 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77091 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=101932 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60255 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21001 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72067 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21930 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120227 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132784 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88924 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24215 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51163 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80509 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21327 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81566 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20404 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42620 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=33921 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140697 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21452 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27192 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71340 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53947 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51184 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=41157 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20085 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95390 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22475 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70989 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61390 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105155 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=133410 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=63599 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20716 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128904 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22097 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52113 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23113 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111829 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=75043 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=138239 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92244 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102236 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105734 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25196 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116405 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20062 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129324 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116285 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22120 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27458 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52468 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21872 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116427 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97047 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137241 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104853 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=117033 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53885 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35760 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98599 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22622 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84978 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84585 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132716 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71035 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=41738 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=29818 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=109096 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22044 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129466 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95387 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76142 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74344 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44891 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137966 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67278 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90049 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=133647 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112888 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=85327 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43210 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77246 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80924 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21760 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123330 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89000 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32903 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50015 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120377 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84334 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52667 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22026 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=107795 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21754 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23709 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=65224 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114980 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25214 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50537 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69300 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22715 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98075 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44567 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25104 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95685 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50356 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51677 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=28757 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=56077 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108604 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=94376 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23510 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20149 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=87994 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46057 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81293 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120056 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137747 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57479 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102993 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97691 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46590 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22913 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78590 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53716 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64978 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20192 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139544 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21605 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69280 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20583 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93520 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25138 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90304 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21079 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=29687 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21633 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=122503 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=54803 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=115487 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=68800 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19922 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57692 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60469 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121794 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79789 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=133007 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27253 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40772 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60832 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100284 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102861 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23142 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76743 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36548 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=26629 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88621 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23120 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34690 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71356 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23980 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=101713 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92280 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104312 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=65809 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40430 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100524 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23434 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=133495 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137910 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27182 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20958 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24020 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97707 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88740 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90052 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25266 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27216 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=83747 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24159 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91350 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67174 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=127706 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46665 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137110 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97242 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22433 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139589 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23702 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21570 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108155 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132518 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20591 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=124313 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=50580 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90186 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128565 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=87400 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20001 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91661 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86265 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=85935 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129836 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70116 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23152 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=28714 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23378 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123008 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105856 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40733 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112077 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=115017 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129373 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=127807 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=54124 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21506 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140125 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20410 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116958 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=130463 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=131132 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129005 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78870 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89749 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25038 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132229 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110426 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140419 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58370 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=127894 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123676 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20768 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61712 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=125416 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92947 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23485 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82309 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22115 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=56824 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88020 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71695 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=111044 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=99468 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35161 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66371 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25335 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=62172 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=54912 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102453 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92638 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24289 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135092 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19870 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98154 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97831 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20557 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52522 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20495 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53906 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76907 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=96647 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22615 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120787 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51567 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78520 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23496 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43063 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=73914 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57598 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51779 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24638 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=25481 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20534 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34206 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21481 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=103628 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=70865 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24963 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129747 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20367 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132013 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21040 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132515 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116111 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88410 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58293 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52281 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59539 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=113746 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35911 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135016 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=45488 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=33060 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116409 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44488 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48376 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23014 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129065 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79355 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21877 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40124 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91538 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=126777 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22447 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42277 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84909 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22026 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95752 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21204 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=37020 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22144 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20781 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48474 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42145 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27053 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21193 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=136395 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79597 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60724 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20186 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132804 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=141015 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=35433 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135951 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20050 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66106 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140671 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21622 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46509 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23086 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52182 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=33995 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121848 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55540 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128881 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59269 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=41923 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=45355 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=73833 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114229 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21733 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=82250 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97310 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88876 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140900 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19944 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24357 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44748 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60592 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=94596 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135214 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24353 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=31487 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80440 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140062 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48841 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22227 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79222 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=37310 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139405 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59519 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=75938 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22485 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88072 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=65141 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21946 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78285 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86639 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32989 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86394 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40876 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19756 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21359 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71159 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20495 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140230 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22017 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98558 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22867 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=38616 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81859 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24358 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=59031 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22840 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84218 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81215 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=124070 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140559 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110227 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84926 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47993 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48596 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20781 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88077 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=38666 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36538 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39946 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=109254 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20204 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64615 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=106963 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22550 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52670 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100005 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53610 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=119632 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69411 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104606 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104306 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86466 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21854 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43092 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=37458 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49780 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32091 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23543 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55356 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=75815 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92568 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78972 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23202 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34709 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57413 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90595 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24853 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=138829 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=30562 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23212 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67073 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112472 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77734 is out of bounds (max index 19625)
# ...
# 🚨 ERROR: article_idx=131990 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42143 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21295 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110401 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=115567 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137527 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=113597 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20167 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27805 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128283 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22872 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90277 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=26539 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92226 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120407 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20921 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=26665 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=44897 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55185 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105380 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112812 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105206 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20457 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22026 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=96245 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=116831 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66391 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108313 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20196 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=90775 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23540 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=53817 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135906 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49425 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=61365 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97443 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23545 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=132607 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24900 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79550 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22291 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91683 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=40558 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=69302 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114349 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84887 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98917 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=106775 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=31879 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120413 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=56156 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20994 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22809 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=138964 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21163 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97580 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80558 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47774 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71278 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=81400 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84674 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22433 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=38815 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=41413 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=76815 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24888 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89910 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43574 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=131521 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42555 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=94223 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=47305 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=54990 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=98095 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21801 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21899 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66501 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49001 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23334 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=128937 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23149 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=38639 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129435 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57054 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21488 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=85752 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21946 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=45789 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36305 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=49746 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=29587 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=97800 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89679 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20018 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=94902 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20721 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=91738 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92410 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60855 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21659 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121251 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=42711 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84616 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=104031 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=84317 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=123326 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102803 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24640 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=19755 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57642 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20442 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=73429 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121380 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79895 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20865 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79758 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36716 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78400 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46614 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=28783 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89857 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58480 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=136308 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=38731 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48488 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137906 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51209 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23357 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74976 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93048 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=48735 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=140043 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=101564 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=129477 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=83453 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=136932 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=92352 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21887 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20511 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=52550 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=66211 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121403 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=55068 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=88923 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=56733 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23382 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=102929 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=32404 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=134909 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=77493 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108509 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135815 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=96582 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=43668 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23287 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=86948 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78429 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=80934 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=139893 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=21735 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=130112 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23241 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=135426 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=62256 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=119467 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=114677 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20221 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=120536 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=27324 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=110377 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24065 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=137121 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24054 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=117451 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=74530 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=71038 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24129 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=62657 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=65617 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=51106 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108597 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=30580 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=34445 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=75750 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=105562 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=112267 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=57733 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=134808 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23257 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=64932 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=79660 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121234 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24283 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=23257 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=39283 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=37029 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=58126 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=60513 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=65676 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=72422 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=46899 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=22123 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=67191 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=100774 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=99444 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=131220 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=20101 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93268 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=78101 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=93065 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=89744 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=95443 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=117245 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=24700 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=121797 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=36928 is out of bounds (max index 19625)
# 🚨 ERROR: article_idx=108753 is out of bounds (max index 19625)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-100-e9ebc3965bec> in <cell line: 46>()
#      44
#      45 # ✅ Train the model with early stopping
# ---> 46 trained_model = train_full_batch_with_early_stopping(
#      47     model=model,
#      48     optimizer=optimizer,
#
# <ipython-input-99-2a7e43dd7cd6> in train_full_batch_with_early_stopping(model, optimizer, num_epochs, patience, start_epoch)
#      66         # ✅ Backpropagation
#      67         train_loss_acc.backward()
# ---> 68         optimizer.step()
#      69
#      70         avg_train_loss = train_loss_acc.item() / max(len(train_data), 1)
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     485                             )
#     486
# --> 487                 out = func(*args, **kwargs)
#     488                 self._optimizer_step_code()
#     489
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      89             torch.set_grad_enabled(self.defaults["differentiable"])
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#      93             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adam.py in step(self, closure)
#     195                 and returns the loss.
#     196         """
# --> 197         self._cuda_graph_capture_health_check()
#     198
#     199         loss = None
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _cuda_graph_capture_health_check(self)
#     428             and torch.cuda.is_available()
#     429         ):
# --> 430             capturing = torch.cuda.is_current_stream_capturing()
#     431
#     432             if capturing and not all(
#
# /usr/local/lib/python3.10/dist-packages/torch/cuda/graphs.py in is_current_stream_capturing()
#      28     If a CUDA context does not exist on the current device, returns False without initializing the context.
#      29     """
# ---> 30     return _cuda_isCurrentStreamCapturing()
#      31
#      32
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
print(train_data.columns)
# Out:
# Index(['t_dat', 'customer_id', 'article_id', 'price', 'sales_channel_id',
#        'rank', 'FN', 'Active', 'club_member_status', 'fashion_news_frequency',
#        'age', 'postal_code', 'normalized_age'],
#       dtype='object')

# %%
# Metrics Evaluation Functions
def recall_at_k(recommended_articles, relevant_articles, k=10):
    recommended_set = set(recommended_articles[:k])
    relevant_set = set(relevant_articles)
    intersection = recommended_set.intersection(relevant_set)
    return len(intersection) / len(relevant_set) if len(relevant_set) > 0 else 0.0

def ndcg_at_k(recommended_articles, relevant_articles, k=10):
    recommended_set = set(recommended_articles[:k])
    dcg = 0.0
    idcg = 0.0

    for i in range(min(k, len(recommended_articles))):
        if recommended_articles[i] in relevant_articles:
            dcg += 1 / np.log2(i + 2)

    for i in range(min(k, len(relevant_articles))):
        idcg += 1 / np.log2(i + 2)

    return dcg / idcg if idcg > 0 else 0.0

# %%
# Full-batch evaluation with Recall@K and NDCG@K metrics using Sliced Wasserstein Distance (SWD)
def test_model_full_batch_with_metrics(model, k=10):
    model.eval()
    total_test_loss = 0.0
    all_recall_at_k = []
    all_ndcg_at_k = []

    test_features_tensor = torch.tensor(test_features, dtype=dtype).to(device)

    with torch.no_grad():
        # Compute embeddings for each edge type separately
        test_embeddings_product_to_product = model(test_features_tensor, product_to_product_edge_index)
        test_embeddings_customer_to_product = model(test_features_tensor, customer_to_product_edge_index)
        # test_embeddings_customer_to_customer = model(test_features_tensor, customer_to_customer_edge_index)

        for _, row in test_data.iterrows():
            customer_id = row["customer_id"]
            article_id = row["article_id"]

            # Get purchased articles for this customer
            customer_transactions = transactions_filtered[transactions_filtered['customer_id'] == customer_id]
            relevant_articles = customer_transactions['article_id'].unique()

            # Map article and customer IDs to indices
            article_idx = article_to_index.get(article_id, -1)
            customer_idx = customer_to_index.get(customer_id, -1)

            if article_idx == -1 or customer_idx == -1:
                continue  # Skip invalid entries

            # Compute **Sliced Wasserstein Distance (SWD)**
            swd_distances_product = []
            swd_distances_customer = []
            swd_distances_customer_to_product = []

            # **Compute SWD for Product-to-Product**
            product_embedding = test_embeddings_product_to_product[article_idx].unsqueeze(0)
            for i in range(test_embeddings_product_to_product.shape[0]):
                if i != article_idx:  # Skip the same article
                    dist = sliced_wasserstein_distance(product_embedding, test_embeddings_product_to_product[i].unsqueeze(0))
                    swd_distances_product.append((i, dist.item()))

            # # **Compute SWD for Customer-to-Customer**
            # customer_embedding = test_embeddings_customer_to_customer[customer_idx].unsqueeze(0)
            # for i in range(test_embeddings_customer_to_customer.shape[0]):
            #     if i != customer_idx:  # Skip the same customer
            #         dist = sliced_wasserstein_distance(customer_embedding, test_embeddings_customer_to_customer[i].unsqueeze(0))
            #         swd_distances_customer.append((i, dist.item()))

            # **Compute SWD for Customer-to-Product**
            for i in range(test_embeddings_product_to_product.shape[0]):
                dist = sliced_wasserstein_distance(customer_embedding, test_embeddings_product_to_product[i].unsqueeze(0))
                swd_distances_customer_to_product.append((i, dist.item()))

            # Sort by SWD distance (lower is better)
            swd_distances_product.sort(key=lambda x: x[1])
            # swd_distances_customer.sort(key=lambda x: x[1])
            swd_distances_customer_to_product.sort(key=lambda x: x[1])

            # Get top-k recommendations
            top_indices_product = [item[0] for item in swd_distances_product[:k]]
            # top_indices_customer = [item[0] for item in swd_distances_customer[:k]]
            top_indices_customer_to_product = [item[0] for item in swd_distances_customer_to_product[:k]]

            recommended_articles = [list(article_to_index.keys())[idx] for idx in top_indices_customer_to_product]

            # **Compute Recall@K and NDCG@K**
            recall = recall_at_k(recommended_articles, relevant_articles, k)
            ndcg = ndcg_at_k(recommended_articles, relevant_articles, k)

            all_recall_at_k.append(recall)
            all_ndcg_at_k.append(ndcg)

            # Retrieve **correct positive and negative indices**
            pos_indices_product = articles_with_images.loc[articles_with_images["article_id"] == article_id, "positive_indices"].values[0]
            neg_indices_product = articles_with_images.loc[articles_with_images["article_id"] == article_id, "negative_indices"].values[0]

            # pos_indices_customer = customers.loc[customers["customer_id"] == customer_id, "positive_indices"].values[0]
            # neg_indices_customer = customers.loc[customers["customer_id"] == customer_id, "negative_indices"].values[0]

            pos_indices_customer_product = customers.loc[customers["customer_id"] == customer_id, "customer_to_product_positive_indices"].values[0]
            neg_indices_customer_product = customers.loc[customers["customer_id"] == customer_id, "negative_customers"].values[0]

            # Compute **Inter-Trajectory and Intra-Trajectory Loss**
            inter_loss_product = inter_trajectory_loss(test_embeddings_product_to_product[article_idx].unsqueeze(0), model.reference_embedding)
            intra_loss_product = intra_trajectory_loss(test_embeddings_product_to_product, pos_indices_product, neg_indices_product, {})

            # inter_loss_customer = inter_trajectory_loss(test_embeddings_customer_to_customer[customer_idx].unsqueeze(0), model.reference_embedding)
            # intra_loss_customer = intra_trajectory_loss(test_embeddings_customer_to_customer, pos_indices_customer, neg_indices_customer, {})

            inter_loss_customer_product = inter_trajectory_loss(test_embeddings_customer_to_product[customer_idx].unsqueeze(0), model.reference_embedding)
            intra_loss_customer_product = intra_trajectory_loss(test_embeddings_customer_to_product, pos_indices_customer_product, neg_indices_customer_product, {})

            # **Total Loss**
            total_test_loss += (inter_loss_product + intra_loss_product +
                                inter_loss_customer + intra_loss_customer +
                                inter_loss_customer_product + intra_loss_customer_product).item()

    # **Normalize Loss**
    avg_test_loss = total_test_loss / max(len(test_data), 1)
    avg_recall_at_k = np.mean(all_recall_at_k)
    avg_ndcg_at_k = np.mean(all_ndcg_at_k)

    # **Print Metrics**
    print(f"✅ Test Loss: {avg_test_loss:.4f}")
    print(f"✅ Recall@{k}: {avg_recall_at_k:.4f}")
    print(f"✅ NDCG@{k}: {avg_ndcg_at_k:.4f}")

    return avg_test_loss, avg_recall_at_k, avg_ndcg_at_k

# %%
# Example usage of testing
test_model_full_batch_with_metrics(
    model=trained_model,
    edge_index=edge_index,
    k=10
)

# %%
def find_similar_embeddings(target_embedding, reference_embeddings, top_n=10):
    """
    Compute Sliced Wasserstein Distance (SWD) between a target embedding and all reference embeddings.
    Returns the indices of the top-N most similar embeddings.
    """
    swd_distances = []
    
    for i in range(reference_embeddings.shape[0]):
        dist = sliced_wasserstein_distance(target_embedding.unsqueeze(0), reference_embeddings[i].unsqueeze(0))
        swd_distances.append((i, dist.item()))

    # ✅ Sort by SWD distance (lower is better)
    swd_distances.sort(key=lambda x: x[1])
    
    return [item[0] for item in swd_distances[:top_n]]  # Return top N indices

# %%
def recommend_articles_any_input(
    model, edge_index, top_n=10, image_path=None, text_input=None, numeric_input=None, 
    age=None, active=None, club_status=None):
    """
    Multi-modal product recommendation function.
    Users can input any combination of image, text, and numeric data.
    Supports cold-start users by recommending based on similar customers if any of `age`, `active`, or `club_status` is provided.
    """
    input_features = []
    test_features_tensor = torch.tensor(test_features, dtype=dtype).to(device)

    # ✅ 1. Process Image Input (if provided)
    if image_path:
        image = Image.open(image_path).convert('RGB')
        image = transform(image).unsqueeze(0).to(device)
        with torch.no_grad():
            image_embedding = resnet_model(image).squeeze(0).cpu().numpy()
        input_features.append(image_embedding)

    # ✅ 2. Process Text Input (if provided)
    if text_input:
        words = text_input.split()  
        word_embeddings = np.zeros(100)  
        valid_word_count = 0

        for word in words:
            if word in embeddings_index:  
                word_embeddings += embeddings_index[word]
                valid_word_count += 1

        if valid_word_count > 0:
            word_embeddings /= valid_word_count  
        input_features.append(word_embeddings)

    # ✅ 3. Process Numeric Input (if provided)
    if numeric_input:
        numeric_input = np.array(numeric_input).reshape(1, -1)
        scaled_numeric_input = scaler.transform(numeric_input)  
        input_features.append(scaled_numeric_input.flatten())

    # ✅ 4. Handle Partial Cold Start (One or More Customer Attributes Given)
    if any([age is not None, active is not None, club_status is not None]):  # If at least one is given
        print("🚀 Partial Cold Start Detected: Generating Customer Embedding...")

        # ✅ Create a DataFrame with the provided inputs
        cold_start_input = pd.DataFrame({"Active": [active], "club_member_status": [club_status]})

        # ✅ One-hot encode categorical features using the **same approach as training**
        dummy_encoded = pd.get_dummies(cold_start_input)
        
        # ✅ Ensure missing categorical columns are handled correctly
        missing_cols = [col for col in categorical_features_encoded.columns if col not in dummy_encoded.columns]
        for col in missing_cols:
            dummy_encoded[col] = 0  # Add missing columns with default 0 values

        # ✅ Ensure column order matches training
        dummy_encoded = dummy_encoded[categorical_features_encoded.columns].astype(np.float32).values

        # ✅ Normalize age if given
        normalized_age = np.zeros(1) if age is None else scaler_age.transform([[age]]).flatten()

        # ✅ Construct customer input feature
        new_customer_features = np.hstack([normalized_age.reshape(-1, 1), dummy_encoded]).astype(np.float32)
        new_customer_features_tensor = torch.tensor(new_customer_features, dtype=torch.float32).to(device)

        # ✅ Generate embedding for the new customer
        with torch.no_grad():
            new_customer_embedding = model(new_customer_features_tensor).squeeze(0)to(device)

        # ✅ Find top-N similar customers
        top_similar_customers = find_similar_embeddings(new_customer_embedding, customer_embeddings, top_n)

        # ✅ Retrieve products purchased by these similar customers
        recommended_articles = transactions_filtered[
            transactions_filtered["customer_id"].isin([customers.iloc[i]["customer_id"] for i in top_similar_customers])
        ]
        recommended_articles = recommended_articles.groupby("article_id").size().reset_index(name="purchase_count")
        recommended_articles = recommended_articles.sort_values("purchase_count", ascending=False).head(top_n)
        recommended_articles = articles_with_images[articles_with_images["article_id"].isin(recommended_articles["article_id"])]

        print("🔹 **Final Recommendations for Partial Cold-Start User** 🔹\n")
        for _, row in recommended_articles.iterrows():
            print(f"🛍️ Product: {row['prod_name']}\n📜 Description: {row['text_data']}\n")
            display(Image.open(row['path']))
            print("\n")

        return recommended_articles[['article_id', 'prod_name']]

    # ✅ 5. If NOT a cold-start user, proceed with normal recommendations
    input_features = np.hstack(input_features)
    input_tensor = torch.tensor(input_features, dtype=torch.float32).unsqueeze(0).to(device)

    # ✅ Compute the full embedding space using the trained model
    with torch.no_grad():
        all_embeddings = model(test_features_tensor, edge_index)

    # ✅ Find top-N similar product indices
    top_indices = find_similar_embeddings(input_tensor, all_embeddings, top_n)

    # ✅ Retrieve recommended products
    recommended_articles = articles_with_images.iloc[top_indices][['article_id', 'prod_name', 'text_data', 'path']]

    print("🔹 **Final Recommendations Based on Multi-Modal Input** 🔹\n")
    for _, row in recommended_articles.iterrows():
        print(f"🛍️ Product: {row['prod_name']}\n📜 Description: {row['text_data']}\n")
        display(Image.open(row['path']))
        print("\n")

    return recommended_articles[['article_id', 'prod_name']]

# %%
# Image Input Recommendation
recommend_articles_any_input(
    model=trained_model,
    edge_index=edge_index,
    top_n=5,
    image_path="/kaggle/input/h-and-m-personalized-fashion-recommendations/images/079/0797892010.jpg"
)

# %%
# Text Input Recommendation
recommend_articles_any_input(
    model=trained_model,
    edge_index=edge_index,
    top_n=5,
    text_input="Floral summer dress with short sleeves"
)

# %%
# Numeric Input Recommendation
numeric_input_example = [22, 5, 14, 8, 1, 3]  # Example input for product_type_no, colour_group_code, etc.
recommend_articles_any_input(
    model=trained_model,
    edge_index=edge_index,
    top_n=5,
    numeric_input=numeric_input_example
)

# %%
# Combined Multi-modal Recommendation
recommend_articles_any_input(
    model=trained_model,
    edge_index=edge_index,
    top_n=5,
    image_path="/kaggle/input/h-and-m-personalized-fashion-recommendations/images/072/0720572001.jpg",
    text_input="Black mini dress",
    numeric_input=[30,40,50]
)

# %%
recommend_articles_any_input(
    model=trained_model,
    edge_index=edge_index,
    top_n=5,
    age=30
)
